# %%
import pandas as pd
df = pd.read_csv("../data/dataset.csv")
df = df.drop(columns=["index"])  # meme nettoyage qu'a l'entrainement
df.sample(20).to_csv("../data/exemple_test_dashboard.csv", index=False)

# %%
df_test = df.sample(20, random_state=1)
vraies_valeurs = df_test["Result"]
df_test_sans_label = df_test.drop(columns=["Result"])
df_test_sans_label.to_csv("../data/exemple_test_dashboard.csv", index=False)

print(vraies_valeurs.value_counts())
# Out:
# Result
# -1    13
#  1     7
# Name: count, dtype: int64
